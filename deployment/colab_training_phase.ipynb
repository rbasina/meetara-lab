# %% [markdown]
# # MeeTARA Lab - Colab Training Phase
# ## Phase 2: Model Training with Pre-Generated Data
#
# This notebook handles model training in Colab using data generated in Phase 1.
#
# ### Prerequisites:
# 1. Data must be generated locally using: `python cloud-training/production_launcher.py --skip-training --domain <domain> --commit`
# 2. Data must be committed and pushed to GitHub
# 3. This notebook will clone the repository and train models

# %% [markdown]
# ## Step 1: Clone Repository and Setup

# %%
# Clone the repository (replace with your actual GitHub URL)
# !git clone https://github.com/your-username/meetara-lab.git
# !cd meetara-lab

# %% [markdown]
# ## Step 2: Install Dependencies

# %%
# Install required packages
# %pip install torch transformers peft datasets accelerate bitsandbytes llama-cpp-python -q
# %pip install -r meetara-lab/requirements.txt -q
